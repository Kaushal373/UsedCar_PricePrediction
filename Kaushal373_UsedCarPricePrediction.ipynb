# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <center><h1> SWIPECAR </h1> </center>
# <h4> Company Introduction : </h4> SWIPECAR, is an American company that buys and sells second hand cars.<br>
# They initiated their business in the late 80s and have gained huge popularity over the years.
# The company clients are local and foreign customers who seek to buy and sell second hand cars.

# %% [markdown]
# <h1> Problem Statement : </h1>
# The current process suffers from the following problems:
#
# They have been using manual traditional measures to estimate old cars prices.
# These measures are time consuming and not accurate.
# Company is looking for a robust way to estimate the prices of used cars.

# %% [markdown]
# # <Center> Data Description </Center>

# %% [markdown]
# <table>	<th>	Column Name	</th>	<th>	Description	</th>
# <tr>	<td>	ID	</td>	<td align = "Center">	Feature uniquely identifying each record	</td>	</tr>
# <tr>	<td>	symbolling	</td>	<td align = "Center">	Degree to which the auto is riskier than its price indicates.	</td>	</tr>
# <tr>	<td>	normalized-losses	</td>	<td align = "Center">	Relative average loss payment per insured vehicle year.	</td>	</tr>
# <tr>	<td>	make	</td>	<td align = "Center">	Make of the car.	</td>	</tr>
# <tr>	<td>	fuel-type	</td>	<td align = "Center">	Type of fuel consumed by the car.	</td>	</tr>
# <tr>	<td>	aspiration	</td>	<td align = "Center">	Type of internal combustion engine used.	</td>	</tr>
# <tr>	<td>	num-of-doors	</td>	<td align = "Center">	Number of doors available in the car.	</td>	</tr>
# <tr>	<td>	body-style	</td>	<td align = "Center">	Body style of car.	</td>	</tr>
# <tr>	<td>	drive-wheels	</td>	<td align = "Center">	Drive wheel of car.	</td>	</tr>
# <tr>	<td>	engine-location	</td>	<td align = "Center">	Location of engine in car.	</td>	</tr>
# <tr>	<td>	wheel-base	</td>	<td align = "Center">	Distance between the centres of the front and rear wheels.	</td>	</tr>
# <tr>	<td>	length	</td>	<td align = "Center">	Length of the car.	</td>	</tr>
# <tr>	<td>	post_code	</td>	<td align = "Center">	Postal Code of the customer.	</td>	</tr>
# <tr>	<td>	width	</td>	<td align = "Center">	Width of the car.	</td>	</tr>
# <tr>	<td>	height	</td>	<td align = "Center">	Height of the car.	</td>	</tr>
# <tr>	<td>	curb-weight	</td>	<td align = "Center">	Total mass of a vehicle with standard equipment.	</td>	</tr>
# <tr>	<td>	engine-type	</td>	<td align = "Center">	Type of engine used in the car.	</td>	</tr>
# <tr>	<td>	num-of-cylinders	</td>	<td align = "Center">	Number of cylinders used in the car.	</td>	</tr>
# <tr>	<td>	engine-size	</td>	<td align = "Center">	Size of the engine used in the car.	</td>	</tr>
# <tr>	<td>	fuel-system	</td>	<td align = "Center">	Type of fuel system used in the car.	</td>	</tr>
# <tr>	<td>	bore	</td>	<td align = "Center">	Diameter of each cylinder in the piston engine.	</td>	</tr>
# <tr>	<td>	stroke	</td>	<td align = "Center">	Full travel of the piston along the cylinder, in either direction.	</td>	</tr>
# <tr>	<td>	compression-ratio	</td>	<td align = "Center">	Volume of the cylinder and the combustion chamber when the piston is at the bottom, and the volume of the combustion chamber when the piston is at the top.	</td>	</tr>
# <tr>	<td>	horsepower	</td>	<td align = "Center">	The power an engine produces by a car.	</td>	</tr>
# <tr>	<td>	peak-rpm	</td>	<td align = "Center">	The max power produced by engine in terms of revolutions per minute.	</td>	</tr>
# <tr>	<td>	city-mpg	</td>	<td align = "Center">	City mileage per gallon rating of car.	</td>	</tr>
# <tr>	<td>	highway-mpg	</td>	<td align = "Center">	Highway mileage per gallon rating of car.	</td>	</tr>
# <tr>	<td>	price	</td>	<td align = "Center">	Price of the car.	</td>	</tr>
# </table>

# %%
train_data = pd.read_csv('TrainData.csv')
train_data.head().T
# Out:
#                            0      1        2       3      4
# ID                         1      2        3       4      5
# symboling                 -1      0        0       0     -2
# normalized-losses         65    188        ?     161    103
# make                  toyota    bmw  renault  peugot  volvo
# fuel-type                gas    gas      gas  diesel    gas
# aspiration               std    std      std   turbo    std
# num-of-doors            four    two     four    four   four
# body-style         hatchback  sedan    wagon   sedan  sedan
# drive-wheels             fwd    rwd      fwd     rwd    rwd
# engine-location        front  front    front   front  front
# wheel-base             102.4  101.2     96.1   107.9  104.3
# length                 175.6  176.8    181.5   186.7  188.8
# width                   66.5   64.8     66.5    68.4   67.2
# height                  53.9   54.3     55.2    56.7   56.2
# curb-weight             2458   2710     2579    3197   2935
# ...

# %%
train_data.tail()
# Out:
#       ID  symboling normalized-losses         make fuel-type aspiration  \
# 176  177          1               129        mazda       gas        std
# 177  178          1               113        mazda       gas        std
# 178  179          1               119     plymouth       gas        std
# 179  180          3                 ?  alfa-romero       gas        std
# 180  181         -1                 ?       toyota       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 176          two    hatchback          fwd           front        98.8
# 177         four        sedan          fwd           front        93.1
# 178          two    hatchback          fwd           front        93.7
# 179          two  convertible          rwd           front        88.6
# 180         four        wagon          rwd           front       104.5
#
#      length  width  height  curb-weight engine-type num-of-cylinders  \
# ...

# %%
test_data = pd.read_csv('TestData.csv')
test_data.head()
# Out:
#    ID  symboling normalized-losses      make fuel-type aspiration  \
# 0   1         -2               103     volvo       gas        std
# 1   2          0               188       bmw       gas        std
# 2   3         -1                74     volvo       gas      turbo
# 3   4          1               154  plymouth       gas        std
# 4   5          1               103    nissan       gas        std
#
#   num-of-doors body-style drive-wheels engine-location  wheel-base  length  \
# 0         four      sedan          rwd           front       104.3   188.8
# 1         four      sedan          rwd           front       101.2   176.8
# 2         four      wagon          rwd           front       104.3   188.8
# 3         four      sedan          fwd           front        93.7   167.3
# 4         four      wagon          fwd           front        94.5   170.2
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# ...

# %%
test_data.tail()
# Out:
#     ID  symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 15  16          0                 ?     bmw       gas        std         four
# 16  17          1               168  toyota       gas        std          two
# 17  18          0                 ?  peugot       gas        std         four
# 18  19          2               192     bmw       gas        std          two
# 19  20          0                91  toyota    diesel        std         four
#
#    body-style drive-wheels engine-location  wheel-base  length  width  height  \
# 15      sedan          rwd           front       103.5   189.0   66.9    55.7
# 16  hatchback          rwd           front        94.5   168.7   64.0    52.6
# 17      wagon          rwd           front       114.2   198.9   68.4    56.7
# 18      sedan          rwd           front       101.2   176.8   64.8    54.3
# 19      sedan          fwd           front        95.7   166.3   64.4    53.0
#
# ...

# %% [markdown]
# ## Profiling of the Data

# %%
from pandas_profiling import profile_report

# %%
#PR = train_data.profile_report(title = 'ProfilingofCars')

# %%
#PR.to_file('Profiling.html')

# %% [markdown]
# ## Dataset statistics
#
# Number of variables	- 27 <br>
# Number of observations - 181 <br>
#
# ### Variable types
#
# Numeric	12 <br>
# Categorical	15

# %% [markdown]
# ### Variable Information :
#
# - ID - Unique Identification of each entries<br>
# - Symboling -  -2 to 3 Range - 5<br>
# - Normalized-losses - distinct 52. Numerical Has Junk Values (?)<br>
# - Make - Make of the Model . 22 Models. Highest share is of 28<br>
# - fuel-type - Gas and Diesel . 90% of car has fuel type as Gas<br>
# - aspiration -  std and turbo . highest is standard 81.2%
# - numofdoors - Has some junk values 2 doors(42.5%) and 4 Doors(57%)
# - body-style - 5 Values. Sedan has highest entries followed by wagon & hatchback
# - drive-wheels - 3 fwd , rwd, 4wd
# - engine location - front - 178 rear - 3
# - wheel-base  - Min - 87, median- 96.9, Mean - 98.72, Range -34.3 Max -120
# - length - Min - 141.1, median - 173.2, mean - 174, Range - 67, Max -208
# - width -  Min - 60.3, Median - 65.5 , Mean -  65.94, Range - 11.7, Max - 72
# - height - Min - 47.8, Median - 54.1, Mean -  53.70, Range - 12, Max - 59.8
# - curb_weight - Min - 1488, Median - 2420 , Mean - 2564, Range - 2578, Max -4066
# - eng-type - 6 type ,  max -  ohc
# - num-of-cylinders -  7 Types , Max - Four
# - engine-size - Min - 61, median - 120, mean - 127, Range - 265, Max -326
# - fuel_system - 8 types. Max mpfi - 45%
# - bore -  Need to change it to numerical variable
# - stroke - Need to change it to numerical variable
# - compression-ratio - Min - 7, Median - 9, mean -  10.15, Max - 23, Range - 16
# - horsepower -  Need to change to Numerical variable
# - peak-rpm - Need to be converted to numerical variable
# - city-mpg - Min - 13, Median - 24, mean - 25.13, Max- 49, range - 36
# - highway-mpg -  Min -16 , Median - 30 , mean - 30, Range -38 , max- 54
# - <b> <i> <u> Price -  </u></i></b>  Target Variable

# %% [markdown]
# ### Info of the Data

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 181 non-null    int64
#  1   symboling          181 non-null    int64
#  2   normalized-losses  181 non-null    object
#  3   make               181 non-null    object
#  4   fuel-type          181 non-null    object
#  5   aspiration         181 non-null    object
#  6   num-of-doors       181 non-null    object
#  7   body-style         181 non-null    object
#  8   drive-wheels       181 non-null    object
#  9   engine-location    181 non-null    object
#  10  wheel-base         181 non-null    float64
#  11  length             181 non-null    float64
#  12  width              181 non-null    float64
#  13  height             181 non-null    float64
#  14  curb-weight        181 non-null    int64
#  15  engine-type        181 non-null    object
# ...

# %%
train_data.describe()
# Out:
#                ID   symboling  wheel-base      length       width      height  \
# count  181.000000  181.000000  181.000000  181.000000  181.000000  181.000000
# mean    91.000000    0.850829   98.729282  174.174033   65.943646   53.709945
# std     52.394338    1.267045    6.116197   12.336569    2.146114    2.497735
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     46.000000    0.000000   94.500000  166.800000   64.200000   51.600000
# 50%     91.000000    1.000000   96.900000  173.200000   65.500000   54.100000
# 75%    136.000000    2.000000  102.400000  183.100000   66.600000   55.500000
# max    181.000000    3.000000  120.900000  208.100000   72.000000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg  \
# count   181.000000   181.000000         181.000000  181.000000   181.000000
# mean   2564.165746   127.900552          10.154254   25.132597    30.646409
# ...

# %% [markdown]
# # Datapreprocessing

# %%
train_data1 = train_data.copy()

# %%
train_data1.columns
# Out:
# Index(['ID', 'symboling', 'normalized-losses', 'make', 'fuel-type',
#        'aspiration', 'num-of-doors', 'body-style', 'drive-wheels',
#        'engine-location', 'wheel-base', 'length', 'width', 'height',
#        'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size',
#        'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower',
#        'peak-rpm', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# ### Finding '?' and replacing with NaN

# %%
Columns = ['normalized-losses','bore','stroke','horsepower','peak-rpm']

# %%
for i in Columns:
    train_data1[i]=train_data1[i].str.replace('?','NaN').astype('float')

# %%
train_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 181 non-null    int64
#  1   symboling          181 non-null    int64
#  2   normalized-losses  147 non-null    float64
#  3   make               181 non-null    object
#  4   fuel-type          181 non-null    object
#  5   aspiration         181 non-null    object
#  6   num-of-doors       181 non-null    object
#  7   body-style         181 non-null    object
#  8   drive-wheels       181 non-null    object
#  9   engine-location    181 non-null    object
#  10  wheel-base         181 non-null    float64
#  11  length             181 non-null    float64
#  12  width              181 non-null    float64
#  13  height             181 non-null    float64
#  14  curb-weight        181 non-null    int64
#  15  engine-type        181 non-null    object
# ...

# %%
train_data1[Columns].describe()
# Out:
#        normalized-losses        bore      stroke  horsepower     peak-rpm
# count         147.000000  177.000000  177.000000  179.000000   179.000000
# mean          120.863946    3.338983    3.274463  104.167598  5106.703911
# std            35.086515    0.265255    0.309848   37.967385   473.256441
# min            65.000000    2.680000    2.190000   48.000000  4150.000000
# 25%            94.000000    3.150000    3.110000   71.000000  4800.000000
# 50%           115.000000    3.330000    3.350000   95.000000  5100.000000
# 75%           148.000000    3.590000    3.460000  116.000000  5500.000000
# max           256.000000    3.940000    4.170000  262.000000  6600.000000

# %% [markdown]
# ### Replacing the NaN values with Mean Values since data seems to be normally distributed except for Horsepower

# %%
train_data1['normalized-losses'].fillna(train_data1['normalized-losses'].mean(), inplace=True)

# %%
train_data1['bore'].fillna(train_data1['bore'].mean(), inplace=True)

# %%
train_data1['stroke'].fillna(train_data1['stroke'].mean(), inplace=True)

# %%
train_data1['horsepower'].fillna(train_data1['horsepower'].median(), inplace=True)

# %%
train_data1['peak-rpm'].fillna(train_data1['peak-rpm'].mean(), inplace=True)

# %%
train_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 181 non-null    int64
#  1   symboling          181 non-null    int64
#  2   normalized-losses  181 non-null    float64
#  3   make               181 non-null    object
#  4   fuel-type          181 non-null    object
#  5   aspiration         181 non-null    object
#  6   num-of-doors       181 non-null    object
#  7   body-style         181 non-null    object
#  8   drive-wheels       181 non-null    object
#  9   engine-location    181 non-null    object
#  10  wheel-base         181 non-null    float64
#  11  length             181 non-null    float64
#  12  width              181 non-null    float64
#  13  height             181 non-null    float64
#  14  curb-weight        181 non-null    int64
#  15  engine-type        181 non-null    object
# ...

# %% [markdown]
# ### Categorical Variable Change - num-of doors

# %%
train_data1['num-of-doors'] = train_data1['num-of-doors'].str.replace('?','four')

# %%
train_data1['num-of-doors'].value_counts()
# Out:
# four    104
# two      77
# Name: num-of-doors, dtype: int64

# %%
train_data1['drive-wheels'].value_counts()
# Out:
# fwd    108
# rwd     65
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
train_data1['drive-wheels'] = train_data1['drive-wheels'].str.replace('4wd','fwd')

# %%
train_data1['drive-wheels'].value_counts()
# Out:
# fwd    116
# rwd     65
# Name: drive-wheels, dtype: int64

# %%
NumCols = train_data1.describe().columns

# %%
CatCols = set(train_data1.columns)-set(train_data1.describe().columns)

# %%
CatCols
# Out:
# {'aspiration',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'engine-type',
#  'fuel-system',
#  'fuel-type',
#  'make',
#  'num-of-cylinders',
#  'num-of-doors'}

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Q1 - What is the split of Categorical Variables in the Dataset

# %%
f,axes = plt.subplots(2,4,figsize=(18,10))
plt.xticks(rotation=90)
sns.countplot(x=train_data1['engine-location'],ax=axes[0,0])
sns.countplot(x=train_data1['drive-wheels'],ax=axes[0,1])
sns.countplot(x=train_data1['num-of-doors'],ax=axes[0,2])
sns.countplot(x=train_data1['engine-type'],ax=axes[0,3])
plt.xticks(rotation=90)
sns.countplot(x=train_data1['num-of-cylinders'],ax=axes[1,0])
plt.xticks(rotation=90)
sns.countplot(x=train_data1['fuel-system'],ax=axes[1,1])
sns.countplot(x=train_data1['aspiration'],ax=axes[1,2])
sns.countplot(x=train_data1['body-style'],ax=axes[1,3])

;
# Out:
# ''

# %% [markdown]
# # Insights -
# - 1 - Dataset has majorly Front wheel cars with majorly 4 Cylinders
# - 2 - Std Aspiration is majorly in the dataset
# - 3 - Ohc is the majorly Engine type in the system
# - 4 - Four Doors are more compared to two doors and same with drive wheels
# - 5 -  Sedan is highest followed by hatchback

# %% [markdown]
# ### Q2 -  What is Relationship of Categorical Variable  with Target Variable

# %%
f,axes = plt.subplots(2,4,figsize=(18,10))
plt.xticks(rotation=90)
sns.boxplot(x=train_data1['engine-location'],y=train_data1['price'],ax=axes[0,0])
sns.boxplot(x=train_data1['drive-wheels'],y=train_data1['price'],ax=axes[0,1])
sns.boxplot(x=train_data1['num-of-doors'],y=train_data1['price'],ax=axes[0,2])
sns.boxplot(x=train_data1['engine-type'],y=train_data1['price'],ax=axes[0,3])
sns.boxplot(x=train_data1['num-of-cylinders'],y=train_data1['price'],ax=axes[1,0])
sns.boxplot(x=train_data1['fuel-system'],y=train_data1['price'],ax=axes[1,1])
sns.boxplot(x=train_data1['aspiration'],y=train_data1['price'],ax=axes[1,2])
sns.boxplot(x=train_data1['body-style'],y=train_data1['price'],ax=axes[1,3]);

# %% [markdown]
# # Insights
#  - 1 - Price of Rear engine location are more as compared to Front Location
#  - 2 - Fwd Drive Wheels price range is comparatively less with rwd drive wheels
#  - 3 - Price of Number of Doors are almost same in both the cases
#  - 4 - Price Increases with range in number of cylinders
#  - 5 - Turbo Aspiration Price Range is comparatively higher as compared to std Aspiration
#  - 6 - Price for Hatchback is the lowest followed by Hatchback

# %% [markdown]
# ### Q3 -  What is the Distribution of the data makewise

# %%
plt.figure(figsize=(8,4))
train_data1['make'].value_counts().sort_values(ascending=False).plot(kind='bar');

# %% [markdown]
# ### Insights - Toyota has the highest share followed by Nissan and Mazda

# %% [markdown]
# ### Q4 - What is the distribution of the Engine type with the respect to Price

# %%
sns.boxplot(y=train_data1['price'],x=train_data1['fuel-type'])
# Out:
# <AxesSubplot:xlabel='fuel-type', ylabel='price'>

# %% [markdown]
# ### Insights - Cars with Diesel Price is comparatively higher with respect to gas.

# %%
train_data1.columns
# Out:
# Index(['ID', 'symboling', 'normalized-losses', 'make', 'fuel-type',
#        'aspiration', 'num-of-doors', 'body-style', 'drive-wheels',
#        'engine-location', 'wheel-base', 'length', 'width', 'height',
#        'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size',
#        'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower',
#        'peak-rpm', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# ### Q5 - What is the coorelation of Price with Respect to other Variables

# %%
train_data1.corr()['price'].plot(kind='barh');

# %% [markdown]
# ## Converting the Categorical Variables into Numerical Variable

# %%
train_data2 = train_data1.copy()

# %%
train_data2.drop(['ID'],axis=1, inplace=True) # Droping the ID

# %%
train_data2 = pd.get_dummies(train_data2,drop_first=True)

# %%
train_data2.isnull().sum().any()
# Out:
# False

# %% [markdown]
# ## Dividing the Data in to X and Y variable

# %%
X = train_data2.drop('price',axis=1)
print(X.shape)
# Out:
# (181, 63)

# %%
y = train_data2['price']
print(Y.shape)
# Out:
# (181,)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
print(vif_data)
# Out:
# C:\ProgramData\Anaconda4\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#                     feature           VIF
# 0                 symboling  7.716481e+00
# 1         normalized-losses  3.862617e+00
# 2                wheel-base  2.497388e+01
# 3                    length  2.936006e+01
# 4                     width  1.656983e+01
# 5                    height  9.115838e+00
# 6               curb-weight  4.161233e+01
# 7               engine-size  1.699473e+02
# 8                      bore  5.047569e+01
# 9                    stroke  1.045843e+01
# 10        compression-ratio  2.461442e+02
# 11               horsepower  6.150761e+01
# 12                 peak-rpm  7.116607e+00
# 13                 city-mpg  4.987893e+01
# 14              highway-mpg  4.189723e+01
# 15                make_audi  1.346124e+01
# 16                 make_bmw  1.428813e+01
# ...

# %% [markdown]
# ## Since Most of the Data is normally distributed hence using the Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
SS = StandardScaler()

# %%
X[X.columns] = SS.fit_transform(X)

# %%
X.head()
# Out:
#    symboling  normalized-losses  wheel-base    length     width    height  \
# 0  -1.464797          -1.772777    0.601828  0.115909  0.259957  0.076302
# 1  -0.673369           2.130485    0.405084  0.213451 -0.534370  0.236891
# 2  -0.673369           0.000000   -0.431081  0.595489  0.259957  0.598217
# 3  -0.673369           1.273671    1.503575  1.018169  1.147734  1.200428
# 4  -2.256224          -0.566892    0.913341  1.188867  0.587032  0.999691
#
#    curb-weight  engine-size      bore    stroke  compression-ratio  \
# 0    -0.203367    -0.138965 -0.110806  0.869079          -0.366192
# 1     0.279354     0.850186 -0.110806 -0.276441          -0.290650
# 2     0.028416     0.096547  0.462664  2.047329          -0.366192
# 3     1.212231     0.567571  1.380215  0.803621           2.731038
# 4     0.710355     0.308508  1.686065 -0.407358          -0.164746
#
#    horsepower      peak-rpm  city-mpg  highway-mpg  make_audi  make_bmw  \
# ...

# %% [markdown]
# # Linear Regression Model Building

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()

# %%
LR.fit(X,y)
# Out:
# LinearRegression()

# %%
Pred_Values = LR.predict(X)

# %%
Pred_Values
# Out:
# array([ 9841.39972272, 23382.39972272,  8419.39972272, 16602.49017348,
#        16319.39972272,  8953.39972272, 33282.39972272, 33606.39972272,
#         9308.39972272,  9198.55269173,  7346.49017348,  9596.39972272,
#        11749.39972272, 12659.33391821, 18017.39972272, 11548.39972272,
#         7345.33391821, 29682.49017348,  8976.33391821,  4209.33391821,
#        18109.39972272, 27610.49017348, 16875.39972272, 15590.39972272,
#         6891.33391821, 13168.39972272, 18992.39972272,  8937.33391821,
#        15573.39972272, 36194.39972272,  7639.33391821,  8384.33391821,
#         6005.33391821, 17994.39972272, 15999.39972272,  8662.39972272,
#        25214.39972272, 17448.39972272, 15594.49017348, 13428.69994937,
#         7266.33391821,  9464.33391821, 15656.39972272,  9029.55269173,
#        13899.55269173,  7255.33391821,  9548.39972272,  9922.39972272,
#         7573.33391821, 34959.39972272, 10847.33391821, 16752.39972272,
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mse = mean_squared_error(y,Pred_Values)

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 1356.6676419937692

# %% [markdown]
# ## Predicting the test model

# %%
test_data1 = test_data.copy()

# %%
test_data1.shape
# Out:
# (20, 26)

# %%
test_data1['normalized-losses']=test_data1['normalized-losses'].str.replace('?','NaN').astype('float')

# %%
test_data1.fillna(test_data1['normalized-losses'].mean(), inplace=True)

# %%
test_data1 = pd.get_dummies(test_data1.drop(['ID'],axis=1), drop_first=True)

# %%
test_data1.shape
# Out:
# (20, 39)

# %%
missing_cols = set(X.columns) - set(test_data1.columns)

# %%
missing_cols
# Out:
# {'body-style_hardtop',
#  'body-style_hatchback',
#  'engine-location_rear',
#  'engine-type_ohcf',
#  'engine-type_ohcv',
#  'engine-type_rotor',
#  'fuel-system_4bbl',
#  'fuel-system_mfi',
#  'fuel-system_spdi',
#  'fuel-system_spfi',
#  'make_audi',
#  'make_chevrolet',
#  'make_dodge',
#  'make_isuzu',
#  'make_jaguar',
#  'make_mercedes-benz',
#  'make_mercury',
#  'make_porsche',
#  'make_renault',
#  'make_subaru',
#  'num-of-cylinders_five',
#  'num-of-cylinders_three',
#  'num-of-cylinders_twelve',
#  'num-of-cylinders_two'}

# %%
for col in missing_cols:
    test_data1[col] = 0
    test_data1= test_data1[test_data1.columns]

# %%
test_data2 = test_data1[X.columns]

# %%
test_data2[test_data2.columns] = SS.transform(test_data2)

# %%
test_data2.head()
# Out:
#    symboling  normalized-losses  wheel-base    length     width    height  \
# 0  -2.256224          -0.566892    0.913341  1.188867  0.587032  0.999691
# 1  -0.673369           2.130485    0.405084  0.213451 -0.534370  0.236891
# 2  -1.464797          -1.487173    0.913341  1.188867  0.587032  1.521606
# 3   0.118058           1.051534   -0.824570 -0.558754 -1.001621 -1.168265
# 4   0.118058          -0.566892   -0.693407 -0.323028 -1.001621 -0.084287
#
#    curb-weight  engine-size      bore    stroke  compression-ratio  \
# 0     0.666297     0.308508  1.686065 -0.407358          -0.164746
# 1     0.384710     0.850186 -0.110806 -0.276441          -0.290650
# 2     1.135609     0.049445  1.074364 -0.407358          -0.668361
# 3    -1.101764    -0.892604 -1.410670 -0.145525          -0.189927
# 4    -1.009817    -0.727746 -0.722507  0.050850          -0.189927
#
#    horsepower  peak-rpm  city-mpg  highway-mpg  make_audi  make_bmw  \
# ...

# %%
Idvalues = pd.DataFrame(test_data['ID'])

# %%
predvalues = pd.DataFrame(LR.predict(test_data2))

# %%
predvalues
# Out:
#                0
# 0   16335.399723
# 1   23624.399723
# 2   18281.399723
# 3    5850.333918
# 4    5799.333918
# 5    9730.490173
# 6   12202.399723
# 7   12777.399723
# 8   11945.333918
# 9   10162.333918
# 10  37116.399723
# 11   5914.333918
# 12  10660.333918
# 13  10183.333918
# 14   1513.399723
# 15  32911.399723
# 16  12349.399723
# 17  16913.399723
# 18  18885.399723
# 19   6242.490173

# %%
Idvalues['PredictedValues'] = predvalues

# %%
Idvalues.to_csv('submission.csv', index=False, header=False)
